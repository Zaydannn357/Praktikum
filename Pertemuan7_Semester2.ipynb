# %% [markdown]
# <a href="https://colab.research.google.com/github/Zaydannn357/Praktikum/blob/main/Pertemuan7_Semester2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Membuat Binary Tree Secara Manual

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None

# Membuat tree secara manual
root = Node(1)
root.left = Node(2)
root.right = Node(3)
root.left.left = Node(4)
root.left.right = Node(5)

# Fungsi inorder traversal
def inorder(node):
    if node:
        inorder(node.left)
        print(node.data, end=' ')
        inorder(node.right)

print("Hasil inorder traversal dari binary tree:")
inorder(root)
# Out:
# Hasil inorder traversal dari binary tree:
# 4 2 5 1 3

# %% [markdown]
# Membuat Binary Search Tree

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None

class BinarySearchTree:
    def __init__(self):
        self.root = None

    def insert(self, root, data):
        if root is None:
            return Node(data)

        if data < root.data:
            root.left = self.insert(root.left, data)
        else:
            root.right = self.insert(root.right, data)

        return root

bst = BinarySearchTree()
root = None

data_list = [50, 30, 70, 20, 40, 60, 80]

for value in data_list:
    root = bst.insert(root, value)

# %% [markdown]
# Traversal pada BST

# %%
def inorder(node):
    if node:
        inorder(node.left)
        print(node.data, end=' ')
        inorder(node.right)

def preorder(node):
    if node:
        print(node.data, end=' ')
        preorder(node.left)
        preorder(node.right)

def postorder(node):
    if node:
        postorder(node.left)
        postorder(node.right)
        print(node.data, end=' ')

print("Inorder Traversal:")
inorder(root)

print("\nPreorder Traversal:")
preorder(root)

print("\nPostorder Traversal:")
postorder(root)
# Out:
# Inorder Traversal:
# 20 30 40 50 60 70 80
# Preorder Traversal:
# 50 30 20 40 70 60 80
# Postorder Traversal:
# 20 40 30 60 80 70 50

# %% [markdown]
# Pencarian Nilai dalam BST

# %%
def search(node, key):
    if node is None or node.data == key:
        return node
    if key < node.data:
        return search(node.left, key)
    return search(node.right, key)

# Uji pencarian
key = 60
result = search(root, key)
if result:
    print(f"{key} ditemukan dalam tree.")
else:
    print(f"{key} tidak ditemukan.")

key = 25
result = search(root, key)
if result:
    print(f"{key} ditemukan dalam tree.")
else:
    print(f"{key} tidak ditemukan.")
# Out:
# 60 ditemukan dalam tree.
# 25 tidak ditemukan.

# %% [markdown]
# Tugas 1

# %%
# Struktur Tree berdasarkan identitas saya

class Node:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None

# Membuat tree manual
root = Node(19)      # Jumlah huruf nama
root.left = Node(6)  # Jumlah huruf vokal
root.right = Node(60) # Dua digit terakhir NPM

# Level berikutnya
root.left.left = Node(7)  # Tanggal lahir
root.right.right = Node(8) # Bulan lahir

# Inorder traversal
def inorder(node):
    if node:
        inorder(node.left)
        print(node.data, end=" ")
        inorder(node.right)

print("Hasil Inorder Traversal:")
inorder(root)
# Out:
# Hasil Inorder Traversal:
# 7 6 19 60 8

# %% [markdown]
# Tugas 2

# %%
# Program BST berdasarkan identitas pribadi

class Node:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None

class BinarySearchTree:
    def insert(self, root, data):
        # Menambahkan data ke BST
        if root is None:
            return Node(data)

        if data < root.data:
            root.left = self.insert(root.left, data)
        else:
            root.right = self.insert(root.right, data)

        return root

# Membuat objek BST
bst = BinarySearchTree()
root = None

# Data berdasarkan identitas
# 060 -> 60
# Tanggal lahir -> 7 dan 8
# ASCII G = 71
# ASCII u = 117
# Angka bebas = 10 dan 99

data_list = [60, 7, 8, 71, 117, 10, 99]

# Memasukkan data ke BST
for value in data_list:
    root = bst.insert(root, value)

# Traversal inorder
def inorder(node):
    if node:
        inorder(node.left)
        print(node.data, end=" ")
        inorder(node.right)

# Traversal preorder
def preorder(node):
    if node:
        print(node.data, end=" ")
        preorder(node.left)
        preorder(node.right)

# Traversal postorder
def postorder(node):
    if node:
        postorder(node.left)
        postorder(node.right)
        print(node.data, end=" ")

# Fungsi pencarian data
def search(node, key):
    if node is None or node.data == key:
        return node

    if key < node.data:
        return search(node.left, key)

    return search(node.right, key)

# Menampilkan traversal
print("Inorder Traversal:")
inorder(root)

print("\nPreorder Traversal:")
preorder(root)

print("\nPostorder Traversal:")
postorder(root)

# Pencarian data
key1 = 60
result1 = search(root, key1)

if result1:
    print(f"\n{key1} ditemukan dalam BST")
else:
    print(f"\n{key1} tidak ditemukan")

key2 = 55
result2 = search(root, key2)

if result2:
    print(f"{key2} ditemukan dalam BST")
else:
    print(f"{key2} tidak ditemukan")
# Out:
# Inorder Traversal:
# 7 8 10 60 71 99 117
# Preorder Traversal:
# 60 7 8 10 71 117 99
# Postorder Traversal:
# 10 8 7 99 117 71 60
# 60 ditemukan dalam BST
# 55 tidak ditemukan
