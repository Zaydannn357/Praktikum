# %% [markdown]
# <a href="https://colab.research.google.com/github/Zaydannn357/Praktikum/blob/main/Pertemuan8_Semester2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Representasi Graf dengan Adjacency List

# %%
# Membuat graf tak berarah menggunakan adjacency list
graph = {
    'A': ['B', 'C'],
    'B': ['A', 'D', 'E'],
    'C': ['A', 'F'],
    'D': ['B'],
    'E': ['B', 'F'],
    'F': ['C', 'E']
}

# Menampilkan graf
def print_graph(graf):
    for node in graf:
        print(f"{node} -> {graf[node]}")

print_graph(graph)
# Out:
# A -> ['B', 'C']
# B -> ['A', 'D', 'E']
# C -> ['A', 'F']
# D -> ['B']
# E -> ['B', 'F']
# F -> ['C', 'E']

# %% [markdown]
# Traversal Graf menggunakan BFS

# %%
from collections import deque

def bfs(graph, start):
    visited = set()
    queue = deque([start])

    while queue:
        vertex = queue.popleft()
        if vertex not in visited:
            print(vertex, end=" ")
            visited.add(vertex)
            queue.extend([neighbor for neighbor in graph[vertex] if neighbor not in visited])

# Contoh pemanggilan
bfs(graph, 'A')
# Out:
# A B C D E F

# %% [markdown]
# Traversal Graf menggunakan DFS

# %%
def dfs(graph, start, visited=None):
    if visited is None:
        visited = set()

    if start not in visited:
        print(start, end=" ")
        visited.add(start)
        for neighbor in graph[start]:
            dfs(graph, neighbor, visited)

# Contoh pemanggilan
dfs(graph, 'A')
# Out:
# A B D E F C

# %% [markdown]
# Latihan Personal

# %%
# Lengkapi fungsi untuk menghitung jumlah tetangga dari tiap simpul dalam graf

def count_neighbors(graph):
    result = {}

    for node in graph:
        # Hitung jumlah tetangga
        result[node] = len(graph[node])

    return result

# Contoh Graph
graph = {
    'A': ['B', 'C'],
    'B': ['A', 'C', 'D'],
    'C': ['A', 'B'],
    'D': ['B']
}

print(count_neighbors(graph))
# Out:
# {'A': 2, 'B': 3, 'C': 2, 'D': 1}

# %% [markdown]
# Tugas 1

# %%
# Graph tak berarah
graph = {
    'Zay': ['Tara', 'Noell'],
    'Tara': ['Zay', 'Azri', 'Rasya'],
    'Noell': ['Zay', 'Azri'],
    'Azri': ['Tara', 'Noell', 'Rasya'],
    'Rasya': ['Tara', 'Azri']
}

# Fungsi untuk menampilkan graph

def print_graph(graf):
    for node in graf:
        print(f"{node} -> {graf[node]}")

print("Graph:")
print_graph(graph)
# Out:
# Graph:
# Zay -> ['Tara', 'Noell']
# Tara -> ['Zay', 'Azri', 'Rasya']
# Noell -> ['Zay', 'Azri']
# Azri -> ['Tara', 'Noell', 'Rasya']
# Rasya -> ['Tara', 'Azri']

# %% [markdown]
# Tugas 2

# %%
from collections import deque

# BFS

def bfs(graph, start):
    visited = set()
    queue = deque([start])

    print("Urutan BFS:")

    while queue:
        vertex = queue.popleft()

        if vertex not in visited:
            print(vertex, end=" ")
            visited.add(vertex)
            queue.extend(
                neighbor for neighbor in graph[vertex]
                if neighbor not in visited
            )

# DFS

def dfs(graph, start, visited=None):
    if visited is None:
        visited = set()

    if start not in visited:
        print(start, end=" ")
        visited.add(start)

        for neighbor in graph[start]:
            dfs(graph, neighbor, visited)

print()
bfs(graph, 'Zay')

print("\nUrutan DFS:")
dfs(graph, 'Zay')
# Out:
# Urutan BFS:
# Zay Tara Noell Azri Rasya
# Urutan DFS:
# Zay Tara Azri Noell Rasya

# %% [markdown]
# Tugas 3

# %%
from collections import deque

def bfs_list(graph, start):
    visited = set()
    queue = deque([start])
    result = []

    while queue:
        vertex = queue.popleft()

        if vertex not in visited:
            visited.add(vertex)
            result.append(vertex)

            queue.extend(
                neighbor for neighbor in graph[vertex]
                if neighbor not in visited
            )

    return result

print("\nHasil BFS dalam bentuk list:")
print(bfs_list(graph, 'Zay'))
# Out:
# Hasil BFS dalam bentuk list:
# ['Zay', 'Tara', 'Noell', 'Azri', 'Rasya']

# %% [markdown]
# Tugas 4

# %%
def find_path(graph, start, end, path=None):
    if path is None:
        path = []

    path = path + [start]

    if start == end:
        return path

    for neighbor in graph[start]:
        if neighbor not in path:
            new_path = find_path(graph, neighbor, end, path)

            if new_path:
                return new_path

    return None

print("Jalur dari Zay ke Rasya:")
print(find_path(graph, 'Zay', 'Rasya'))
# Out:
# Jalur dari Zay ke Rasya:
# ['Zay', 'Tara', 'Azri', 'Rasya']

# %% [markdown]
# Tugas 5

# %%
def is_connected(graph):
    visited = set()

    def dfs_connected(node):
        visited.add(node)

        for neighbor in graph[node]:
            if neighbor not in visited:
                dfs_connected(neighbor)

    start_node = next(iter(graph))
    dfs_connected(start_node)

    return len(visited) == len(graph)

print("\nApakah graph terhubung?")
print(is_connected(graph))
# Out:
# Apakah graph terhubung?
# True
